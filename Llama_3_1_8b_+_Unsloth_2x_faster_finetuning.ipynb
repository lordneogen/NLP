# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://github.com/unslothai/unsloth?tab=readme-ov-file#-installation-instructions).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save) (eg for Llama.cpp).
#
# [NEW] Llama-3.1 8b, 70b & 405b are trained on a crazy 15 trillion tokens with 128K long context lengths!
#
# **[NEW] Try 2x faster inference in a free Colab for Llama-3.1 8b Instruct [here](https://colab.research.google.com/drive/1T-YBVfnphoVc8E2E854qF3jdia2Ll2W2?usp=sharing)**

# %%
# %%capture
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"

# %%
# !python3 --version
# Out:
# Python 3.10.12

# %%
# !pip install unsloth
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: unsloth in /home/ramzes/.local/lib/python3.10/site-packages (2024.9.post4)
# Requirement already satisfied: triton>=3.0.0 in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (3.0.0)
# Requirement already satisfied: xformers>=0.0.27.post2 in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (0.0.28.post1)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (0.13.2)
# Requirement already satisfied: bitsandbytes in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (0.44.1)
# Requirement already satisfied: accelerate>=0.34.1 in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (1.0.1)
# Requirement already satisfied: tqdm in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (4.66.5)
# Requirement already satisfied: numpy in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (2.1.2)
# Requirement already satisfied: protobuf<4.0.0 in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (3.20.3)
# Requirement already satisfied: datasets>=2.16.0 in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (3.0.1)
# Requirement already satisfied: huggingface-hub in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (0.25.2)
# Requirement already satisfied: torch>=2.4.0 in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (2.4.1)
# Requirement already satisfied: wheel>=0.42.0 in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (0.44.0)
# Requirement already satisfied: psutil in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (6.0.0)
# Requirement already satisfied: packaging in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (24.1)
# Requirement already satisfied: hf-transfer in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (0.1.8)
# Requirement already satisfied: tyro in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (0.8.12)
# Requirement already satisfied: transformers<4.45.0 in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (4.44.2)
# Requirement already satisfied: trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.11.1,>=0.7.9 in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (0.11.1)
# Requirement already satisfied: sentencepiece>=0.2.0 in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (0.2.0)
# Requirement already satisfied: safetensors>=0.4.3 in /home/ramzes/.local/lib/python3.10/site-packages (from accelerate>=0.34.1->unsloth) (0.4.5)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from accelerate>=0.34.1->unsloth) (5.4.1)
# Requirement already satisfied: multiprocess in /home/ramzes/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (0.70.16)
# Requirement already satisfied: filelock in /home/ramzes/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/ramzes/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (17.0.0)
# Requirement already satisfied: fsspec[http]<=2024.6.1,>=2023.1.0 in /home/ramzes/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (2024.6.1)
# Requirement already satisfied: requests>=2.32.2 in /home/ramzes/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (2.32.3)
# Requirement already satisfied: xxhash in /home/ramzes/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (3.5.0)
# Requirement already satisfied: pandas in /home/ramzes/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: aiohttp in /home/ramzes/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (3.10.10)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/ramzes/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (0.3.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ramzes/.local/lib/python3.10/site-packages (from huggingface-hub->unsloth) (4.12.2)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (9.1.0.70)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (11.0.2.54)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (12.1.3.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (10.3.2.106)
# Requirement already satisfied: networkx in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (3.4.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (12.1.0.106)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (12.1.105)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch>=2.4.0->unsloth) (1.9)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (12.1.105)
# Requirement already satisfied: jinja2 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (3.1.4)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (2.20.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/ramzes/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.4.0->unsloth) (12.6.77)
# Requirement already satisfied: regex!=2019.12.17 in /home/ramzes/.local/lib/python3.10/site-packages (from transformers<4.45.0->unsloth) (2024.9.11)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/ramzes/.local/lib/python3.10/site-packages (from transformers<4.45.0->unsloth) (0.19.1)
# Requirement already satisfied: rich>=11.1.0 in /home/ramzes/.local/lib/python3.10/site-packages (from tyro->unsloth) (13.9.2)
# Requirement already satisfied: shtab>=1.5.6 in /home/ramzes/.local/lib/python3.10/site-packages (from tyro->unsloth) (1.7.1)
# Requirement already satisfied: docstring-parser>=0.16 in /home/ramzes/.local/lib/python3.10/site-packages (from tyro->unsloth) (0.16)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ramzes/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (6.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/ramzes/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /home/ramzes/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.15.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/ramzes/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (24.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ramzes/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/ramzes/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (2.4.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ramzes/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ramzes/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ramzes/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ramzes/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ramzes/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.10)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ramzes/.local/lib/python3.10/site-packages (from rich>=11.1.0->tyro->unsloth) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ramzes/.local/lib/python3.10/site-packages (from rich>=11.1.0->tyro->unsloth) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ramzes/.local/lib/python3.10/site-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ramzes/.local/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/ramzes/.local/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: mdurl~=0.1 in /home/ramzes/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/ramzes/.local/lib/python3.10/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth) (0.2.0)

# %%
# !pip install --no-deps "xformers<0.0.26" --force-reinstall
# !pip install flash_attn==2.6.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting unsloth
#   Using cached unsloth-2024.9.post4-py3-none-any.whl (165 kB)
# Collecting protobuf<4.0.0
#   Using cached protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
# Requirement already satisfied: packaging in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (24.1)
# Collecting hf-transfer
#   Using cached hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Collecting tqdm
#   Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Collecting datasets>=2.16.0
#   Using cached datasets-3.0.1-py3-none-any.whl (471 kB)
# Collecting sentencepiece>=0.2.0
#   Using cached sentencepiece-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting accelerate>=0.34.1
#   Using cached accelerate-1.0.1-py3-none-any.whl (330 kB)
# Collecting trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,<=0.11.1,>=0.7.9
#   Using cached trl-0.11.1-py3-none-any.whl (318 kB)
# Collecting triton>=3.0.0
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 2.4 MB/s eta 0:00:0000:0100:02
# Requirement already satisfied: psutil in /home/ramzes/.local/lib/python3.10/site-packages (from unsloth) (6.0.0)
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (from unsloth) (1.21.5)
# Collecting peft!=0.11.0,>=0.7.1
#   Using cached peft-0.13.2-py3-none-any.whl (320 kB)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.25.2-py3-none-any.whl (436 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.6/436.6 KB 4.0 MB/s eta 0:00:0000:0100:01
# Collecting xformers>=0.0.27.post2
#   Using cached xformers-0.0.28.post1-cp310-cp310-manylinux_2_28_x86_64.whl (16.7 MB)
# Collecting transformers<4.45.0
#   Using cached transformers-4.44.2-py3-none-any.whl (9.5 MB)
# Collecting torch>=2.4.0
#   Using cached torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl (797.1 MB)
# Collecting wheel>=0.42.0
#   Using cached wheel-0.44.0-py3-none-any.whl (67 kB)
# Collecting tyro
#   Using cached tyro-0.8.12-py3-none-any.whl (108 kB)
# Collecting bitsandbytes
#   Using cached bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
# Collecting safetensors>=0.4.3
#   Downloading safetensors-0.4.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (435 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.0/435.0 KB 1.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from accelerate>=0.34.1->unsloth) (5.4.1)
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 3.2 MB/s eta 0:00:0000:0100:01
# Collecting xxhash
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 KB 607.2 kB/s eta 0:00:00a 0:00:01
# Collecting filelock
#   Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.17-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 KB 816.7 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.32.2 in /home/ramzes/.local/lib/python3.10/site-packages (from datasets>=2.16.0->unsloth) (2.32.3)
# Collecting dill<0.3.9,>=0.3.0
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 KB 2.4 MB/s eta 0:00:00a 0:00:01
# Collecting aiohttp
#   Downloading aiohttp-3.10.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 2.1 MB/s eta 0:00:0000:0100:01
# Collecting pyarrow>=15.0.0
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 5.2 MB/s eta 0:00:0000:0100:01
# Collecting fsspec[http]<=2024.6.1,>=2023.1.0
#   Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 KB 3.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ramzes/.local/lib/python3.10/site-packages (from huggingface-hub->unsloth) (4.12.2)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 KB 1.3 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cusolver-cu12==11.4.5.107
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 3.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 5.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-cupti-cu12==12.1.105
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 6.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2 in /home/ramzes/.local/lib/python3.10/site-packages (from torch>=2.4.0->unsloth) (3.1.4)
# Collecting nvidia-cudnn-cu12==9.1.0.70
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:0000:0100:05
# Collecting nvidia-cublas-cu12==12.1.3.1
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.2 MB/s eta 0:00:0000:0100:03
# Collecting networkx
#   Downloading networkx-3.4.1-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12==12.1.0.106
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 1.9 MB/s eta 0:00:0000:0100:04
# Collecting nvidia-cuda-runtime-cu12==12.1.105
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 KB 3.3 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-nvtx-cu12==12.1.105
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 KB 3.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from torch>=2.4.0->unsloth) (1.9)
# Collecting nvidia-curand-cu12==10.3.2.106
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 5.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu12==2.20.5
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 2.1 MB/s eta 0:00:0000:0100:02
# Collecting nvidia-cufft-cu12==11.0.2.54
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvjitlink-cu12
#   Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 5.3 MB/s eta 0:00:0000:0100:01
# Collecting tokenizers<0.20,>=0.19
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 3.8 MB/s eta 0:00:0000:0100:01
# Collecting regex!=2019.12.17
#   Downloading regex-2024.9.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (782 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.7/782.7 KB 5.0 MB/s eta 0:00:00a 0:00:01
# Collecting rich>=11.1.0
#   Downloading rich-13.9.2-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 KB 4.4 MB/s eta 0:00:00a 0:00:01
# Collecting shtab>=1.5.6
#   Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Collecting docstring-parser>=0.16
#   Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Collecting yarl<2.0,>=1.12.0
#   Downloading yarl-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.3/310.3 KB 5.0 MB/s eta 0:00:00a 0:00:01
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/ramzes/.local/lib/python3.10/site-packages (from aiohttp->datasets>=2.16.0->unsloth) (24.2.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 KB 5.2 MB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Collecting async-timeout<5.0,>=4.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 KB 3.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /home/ramzes/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ramzes/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/ramzes/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ramzes/.local/lib/python3.10/site-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.4.0)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.7 MB/s eta 0:00:0000:0100:01
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 KB 1.2 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ramzes/.local/lib/python3.10/site-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 KB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2022.1)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 KB 5.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ramzes/.local/lib/python3.10/site-packages (from pandas->datasets>=2.16.0->unsloth) (2.9.0.post0)
# Collecting numpy
#   Downloading numpy-2.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 4.6 MB/s eta 0:00:0000:0100:01
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.16.0)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (208 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.9/208.9 KB 6.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: sentencepiece, xxhash, wheel, tzdata, tqdm, shtab, safetensors, regex, pygments, protobuf, propcache, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, multidict, mdurl, hf-transfer, fsspec, frozenlist, filelock, docstring-parser, dill, async-timeout, aiohappyeyeballs, yarl, triton, pyarrow, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, markdown-it-py, huggingface-hub, aiosignal, tokenizers, rich, nvidia-cusolver-cu12, aiohttp, tyro, transformers, torch, xformers, datasets, bitsandbytes, accelerate, trl, peft, unsloth
# Successfully installed accelerate-1.0.1 aiohappyeyeballs-2.4.3 aiohttp-3.10.10 aiosignal-1.3.1 async-timeout-4.0.3 bitsandbytes-0.44.1 datasets-3.0.1 dill-0.3.8 docstring-parser-0.16 filelock-3.16.1 frozenlist-1.4.1 fsspec-2024.6.1 hf-transfer-0.1.8 huggingface-hub-0.25.2 markdown-it-py-3.0.0 mdurl-0.1.2 multidict-6.1.0 multiprocess-0.70.16 networkx-3.4.1 numpy-2.1.2 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.77 nvidia-nvtx-cu12-12.1.105 pandas-2.2.3 peft-0.13.2 propcache-0.2.0 protobuf-3.20.3 pyarrow-17.0.0 pygments-2.18.0 regex-2024.9.11 rich-13.9.2 safetensors-0.4.5 sentencepiece-0.2.0 shtab-1.7.1 tokenizers-0.19.1 torch-2.4.1 tqdm-4.66.5 transformers-4.44.2 triton-3.0.0 trl-0.11.1 tyro-0.8.12 tzdata-2024.2 unsloth-2024.9.post4 wheel-0.44.0 xformers-0.0.28.post1 xxhash-3.5.0 yarl-1.15.2
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xformers<0.0.26
#   Downloading xformers-0.0.25.post1-cp310-cp310-manylinux2014_x86_64.whl (222.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.5/222.5 MB 3.7 MB/s eta 0:00:0000:0100:03
# Installing collected packages: xformers
#   Attempting uninstall: xformers
#     Found existing installation: xformers 0.0.28.post1
#     Uninstalling xformers-0.0.28.post1:
#       Successfully uninstalled xformers-0.0.28.post1
# Successfully installed xformers-0.0.25.post1
# Defaulting to user installation because normal site-packages is not writeable
# Collecting flash_attn==2.6.3
#   Downloading flash_attn-2.6.3.tar.gz (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 1.4 MB/s eta 0:00:0000:0100:010m
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [20 lines of output]
#       fatal: not a git repository (or any of the parent directories): .git
#       /tmp/pip-install-bukiv6u1/flash-attn_49535d1b1ea94f9fac0e8df636c338f1/setup.py:95: UserWarning: flash_attn was requested, but nvcc was not found.  Are you sure your environment has nvcc available?  If you're installing within a container from https://hub.docker.com/r/pytorch/pytorch, only images whose names contain 'devel' will provide nvcc.
#         warnings.warn(
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-bukiv6u1/flash-attn_49535d1b1ea94f9fac0e8df636c338f1/setup.py", line 179, in <module>
#           CUDAExtension(
#         File "/home/ramzes/.local/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 1076, in CUDAExtension
#           library_dirs += library_paths(cuda=True)
#         File "/home/ramzes/.local/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 1207, in library_paths
#           if (not os.path.exists(_join_cuda_home(lib_dir)) and
#         File "/home/ramzes/.local/lib/python3.10/site-packages/torch/utils/cpp_extension.py", line 2416, in _join_cuda_home
#           raise OSError('CUDA_HOME environment variable is not set. '
#       OSError: CUDA_HOME environment variable is not set. Please set it to your CUDA install root.
#
#
#       torch.__version__  = 2.4.1+cu121
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install ninja cmake wheel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting ninja
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 KB 967.2 kB/s eta 0:00:00a 0:00:01
# Collecting cmake
#   Downloading cmake-3.30.4-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 2.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wheel in /home/ramzes/.local/lib/python3.10/site-packages (0.44.0)
# Installing collected packages: ninja, cmake
# Successfully installed cmake-3.30.4 ninja-1.11.1.1

# %%
! pip3 install triton
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: triton in /home/ramzes/.local/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: filelock in /home/ramzes/.local/lib/python3.10/site-packages (from triton) (3.16.1)

# %%
# !pip3 install huggingface-hub
# !huggingface-cli download TheBloke/OpenHermes-2.5-Mistral-7B-GGUF openhermes-2.5-mistral-7b.Q4_K_M.gguf --local-dir . --local-dir-use-symlinks False
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: huggingface-hub in /home/ramzes/.local/lib/python3.10/site-packages (0.25.2)
# Requirement already satisfied: packaging>=20.9 in /home/ramzes/.local/lib/python3.10/site-packages (from huggingface-hub) (24.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ramzes/.local/lib/python3.10/site-packages (from huggingface-hub) (4.12.2)
# Requirement already satisfied: requests in /home/ramzes/.local/lib/python3.10/site-packages (from huggingface-hub) (2.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ramzes/.local/lib/python3.10/site-packages (from huggingface-hub) (2024.6.1)
# Requirement already satisfied: filelock in /home/ramzes/.local/lib/python3.10/site-packages (from huggingface-hub) (3.16.1)
# Requirement already satisfied: tqdm>=4.42.1 in /home/ramzes/.local/lib/python3.10/site-packages (from huggingface-hub) (4.66.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from huggingface-hub) (5.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ramzes/.local/lib/python3.10/site-packages (from requests->huggingface-hub) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in /home/ramzes/.local/lib/python3.10/site-packages (from requests->huggingface-hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ramzes/.local/lib/python3.10/site-packages (from requests->huggingface-hub) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ramzes/.local/lib/python3.10/site-packages (from requests->huggingface-hub) (3.4.0)
# /home/ramzes/.local/lib/python3.10/site-packages/huggingface_hub/commands/download.py:139: FutureWarning: Ignoring --local-dir-use-symlinks. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# openhermes-2.5-mistral-7b.Q4_K_M.gguf

# %%
# !pip install -q -U bitsandbytes

# %%
import torch

if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"Total Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
    x = torch.rand(1000, 1000, device='cuda')
    print(f"Memory Allocated: {torch.cuda.memory_allocated(0) / 1024**3:.2f} GB")
    print(f"Memory Reserved: {torch.cuda.memory_reserved(0) / 1024**3:.2f} GB")
else:
    print("CUDA is not available. Using CPU instead.")
# Out:
# GPU Name: NVIDIA GeForce RTX 3050 Laptop GPU
# Total Memory: 4.00 GB
# Memory Allocated: 0.00 GB
# Memory Reserved: 0.02 GB

# %%
import tensorflow as tf

# Узнать, какие устройства доступны (CPU и GPU)
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print(physical_devices)

# Проверить информацию о видеокарте
gpu_info = tf.config.experimental.get_device_details(physical_devices[0])
print(gpu_info)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_10529/3959666376.py in <module>
# ----> 1 import tensorflow as tf
#       2
#       3 # Узнать, какие устройства доступны (CPU и GPU)
#       4 physical_devices = tf.config.experimental.list_physical_devices('GPU')
#       5 print(physical_devices)
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps xformers trl peft accelerate bitsandbytes triton torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-v471ny9z/unsloth_2bd3052acb25459ebc5d5c2dda85d3bb
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-v471ny9z/unsloth_2bd3052acb25459ebc5d5c2dda85d3bb
#   Resolved https://github.com/unslothai/unsloth.git to commit 38663b01f5dd0e610b12475bd95b144303cff539
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   WARNING: Generating metadata for package unsloth produced metadata for project name unknown. Fix your #egg=unsloth fragments.
# Discarding git+https://github.com/unslothai/unsloth.git: Requested unknown from git+https://github.com/unslothai/unsloth.git has inconsistent name: filename has 'unsloth', but metadata has 'unknown'
# ERROR: Could not find a version that satisfies the requirement unsloth (unavailable) (from versions: 2024.8, 2024.9, 2024.9.post1, 2024.9.post2, 2024.9.post3, 2024.9.post4)
# ERROR: No matching distribution found for unsloth (unavailable)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xformers in /home/ramzes/.local/lib/python3.10/site-packages (0.0.28.post1)
# Requirement already satisfied: trl in /home/ramzes/.local/lib/python3.10/site-packages (0.11.1)
# Requirement already satisfied: peft in /home/ramzes/.local/lib/python3.10/site-packages (0.13.3.dev0)
# Requirement already satisfied: accelerate in /home/ramzes/.local/lib/python3.10/site-packages (1.1.0.dev0)
# Requirement already satisfied: bitsandbytes in /home/ramzes/.local/lib/python3.10/site-packages (0.44.1)
# Requirement already satisfied: triton in /home/ramzes/.local/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: torch in /home/ramzes/.local/lib/python3.10/site-packages (2.4.1)

# %%
from unsloth import FastLanguageModel
import torch

# Настройка параметров
max_seq_length = int(2048 / 2)  # Уменьшаем максимальную длину последовательности для экономии памяти
dtype = torch.float16 if torch.cuda.is_available() else None  # Используем float16 для GPU
load_in_4bit = True  # Используем 4bit квантование для снижения потребления памяти

# Предполагаемый размер batch size на основе 4 ГБ VRAM
batch_size = int(2048 / 2)  # Рассчитанный batch size

if torch.cuda.is_available():
    print(f"Модель загружена на GPU: {torch.cuda.get_device_name(0)}")
else:
    print("Модель загружена на CPU.")

# Список предквантованных моделей, поддерживающих 4bit
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit",
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",
]

# Загрузка модели с использованием CUDA, если доступна
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/mistral-7b-instruct-v0.2-bnb-4bit", # Choose ANY! eg teknium/OpenHermes-2.5-Mistral-7B
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# Модель загружена на GPU: NVIDIA GeForce RTX 3050 Laptop GPU
# ==((====))==  Unsloth 2024.9.post4: Fast Mistral patching. Transformers = 4.44.2.
#    \\   /|    GPU: NVIDIA GeForce RTX 3050 Laptop GPU. Max memory: 4.0 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.4.1+cu121. CUDA = 8.6. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post1. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_535/3464586561.py in <module>
#      32
#      33 # Загрузка модели с использованием CUDA, если доступна
# ---> 34 model, tokenizer = FastLanguageModel.from_pretrained(
#      35     model_name = "unsloth/mistral-7b-instruct-v0.2-bnb-4bit", # Choose ANY! eg teknium/OpenHermes-2.5-Mistral-7B
#      36     max_seq_length = max_seq_length,
#
# ~/.local/lib/python3.10/site-packages/unsloth/models/loader.py in from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, token, device_map, rope_scaling, fix_tokenizer, trust_remote_code, use_gradient_checkpointing, resize_model_vocab, revision, *args, **kwargs)
#     318         pass
#     319
# --> 320         model, tokenizer = dispatch_model.from_pretrained(
#     321             model_name        = model_name,
#     322             max_seq_length    = max_seq_length,
#
# ~/.local/lib/python3.10/site-packages/unsloth/models/mistral.py in from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, token, device_map, rope_scaling, fix_tokenizer, model_patcher, tokenizer_name, trust_remote_code, **kwargs)
#     344         **kwargs,
#     345     ):
# --> 346         return FastLlamaModel.from_pretrained(
#     347             model_name        = model_name,
#     348             max_seq_length    = max_seq_length,
#
# ~/.local/lib/python3.10/site-packages/unsloth/models/llama.py in from_pretrained(model_name, max_seq_length, dtype, load_in_4bit, token, device_map, rope_scaling, fix_tokenizer, model_patcher, tokenizer_name, trust_remote_code, **kwargs)
#    1584         if load_in_4bit: kwargs["quantization_config"] = bnb_config
#    1585
# -> 1586         model = AutoModelForCausalLM.from_pretrained(
#    1587             model_name,
#    1588             device_map              = device_map,
#
# ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562         elif type(config) in cls._model_mapping.keys():
#     563             model_class = _get_model_class(config, cls._model_mapping)
# --> 564             return model_class.from_pretrained(
#     565                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566             )
#
# ~/.local/lib/python3.10/site-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3907
#    3908             # Case 1: the GGUF file is present locally
# -> 3909             if os.path.isfile(gguf_file):
#    3910                 gguf_path = gguf_file
#    3911             # Case 2: The GGUF path is a location on the Hub
#
# ~/.local/lib/python3.10/site-packages/transformers/quantizers/quantizer_bnb_4bit.py in validate_environment(self, *args, **kwargs)
#      84         if kwargs.get("from_tf", False) or kwargs.get("from_flax", False):
#      85             raise ValueError(
# ---> 86                 "Converting into 4-bit or 8-bit weights from tf/flax weights is currently not supported, please make"
#      87                 " sure the weights are in PyTorch format."
#      88             )
#
# ValueError: Some modules are dispatched on the CPU or the disk. Make sure you have enough GPU RAM to fit the quantized model. If you want to dispatch the model on the CPU or the disk while keeping these modules in 32-bit, you need to set `load_in_8bit_fp32_cpu_offload=True` and pass a custom `device_map` to `from_pretrained`. Check https://huggingface.co/docs/transformers/main/en/main_classes/quantization#offload-between-cpu-and-gpu for more details.

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the Alpaca dataset from [yahma](https://huggingface.co/datasets/yahma/alpaca-cleaned), which is a filtered version of 52K of the original [Alpaca dataset](https://crfm.stanford.edu/2023/03/13/alpaca.html). You can replace this code section with your own data prep.
#
# **[NOTE]** To train only on completions (ignoring the user's input) read TRL's docs [here](https://huggingface.co/docs/trl/sft_trainer#train-on-completions-only).
#
# **[NOTE]** Remember to add the **EOS_TOKEN** to the tokenized output!! Otherwise you'll get infinite generations!
#
# If you want to use the `llama-3` template for ShareGPT datasets, try our conversational [notebook](https://colab.research.google.com/drive/1XamvWYinY6FOSX9GLvnqSjjsNflxdhNc?usp=sharing).
#
# For text completions like novel writing, try this [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing).

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

from datasets import load_dataset
dataset = load_dataset("yahma/alpaca-cleaned", split = "train")
dataset = dataset.map(formatting_prompts_func, batched = True,)

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
    ),
)
# Out:
# Map (num_proc=2):   0%|          | 0/51760 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")

# %%
trainer_stats = trainer.train()

# %%
#@title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 462.7198 seconds used for training.
# 7.71 minutes used for training.
# Peak reserved memory = 7.922 GB.
# Peak reserved memory for training = 1.938 GB.
# Peak reserved memory % of max memory = 53.716 %.
# Peak reserved memory for training % of max memory = 13.141 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!
#
# **[NEW] Try 2x faster inference in a free Colab for Llama-3.1 8b Instruct [here](https://colab.research.google.com/drive/1T-YBVfnphoVc8E2E854qF3jdia2Ll2W2?usp=sharing)**

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "Continue the fibonnaci sequence.", # instruction
        "1, 1, 2, 3, 5, 8", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

outputs = model.generate(**inputs, max_new_tokens = 64, use_cache = True)
tokenizer.batch_decode(outputs)
# Out:
# ['<|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n\n### Instruction:\nContinue the fibonnaci sequence.\n\n### Input:\n1, 1, 2, 3, 5, 8\n\n### Response:\n13, 21, 34, 55, 89, 144, 233, 377, 610, 987, 1597, 2584, 4181, 6765, 10946, 17711, 28657, 46368, 75025']

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "Continue the fibonnaci sequence.", # instruction
        "1, 1, 2, 3, 5, 8", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128)
# Out:
# <|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Continue the fibonnaci sequence.
#
# ### Input:
# 1, 1, 2, 3, 5, 8
#
# ### Response:
# 13, 21, 34, 55, 89, 144<|end_of_text|>

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model") # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# alpaca_prompt = You MUST copy from above!

inputs = tokenizer(
[
    alpaca_prompt.format(
        "What is a famous tall tower in Paris?", # instruction
        "", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128)
# Out:
# <|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# What is a famous tall tower in Paris?
#
# ### Input:
#
#
# ### Response:
# One of the most famous and iconic tall towers in Paris is the Eiffel Tower. Standing at 324 meters (1,063 feet) tall, this wrought iron tower is a symbol of the city and a must-see attraction for tourists from all over the world.<|end_of_text|>

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %%
if False:
    # I highly do NOT suggest - use Unsloth if possible
    from peft import AutoPeftModelForCausalLM
    from transformers import AutoTokenizer
    model = AutoPeftModelForCausalLM.from_pretrained(
        "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = load_in_4bit,
    )
    tokenizer = AutoTokenizer.from_pretrained("lora_model")

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "", # Get a token at https://huggingface.co/settings/tokens
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in `llama.cpp` or a UI based system like `GPT4All`. You can install GPT4All by going [here](https://gpt4all.io/index.html).
#
# **[NEW] Try 2x faster inference in a free Colab for Llama-3.1 8b Instruct [here](https://colab.research.google.com/drive/1T-YBVfnphoVc8E2E854qF3jdia2Ll2W2?usp=sharing)**

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Zephyr DPO 2x faster [free Colab](https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing)
# 2. Llama 7b 2x faster [free Colab](https://colab.research.google.com/drive/1lBzz5KeZJKXjvivbYvmGarix9Ao6Wxe5?usp=sharing)
# 3. TinyLlama 4x faster full Alpaca 52K in 1 hour [free Colab](https://colab.research.google.com/drive/1AZghoNBQaMDgWJpi4RbffGM1h6raLUj9?usp=sharing)
# 4. CodeLlama 34b 2x faster [A100 on Colab](https://colab.research.google.com/drive/1y7A0AxE3y8gdj4AVkl2aZX47Xu3P1wJT?usp=sharing)
# 5. Mistral 7b [free Kaggle version](https://www.kaggle.com/code/danielhanchen/kaggle-mistral-7b-unsloth-notebook)
# 6. We also did a [blog](https://huggingface.co/blog/unsloth-trl) with 🤗 HuggingFace, and we're in the TRL [docs](https://huggingface.co/docs/trl/main/en/sft_trainer#accelerate-fine-tuning-2x-using-unsloth)!
# 7. `ChatML` for ShareGPT datasets, [conversational notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing)
# 8. Text completions like novel writing [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing)
# 9. [**NEW**] We make Phi-3 Medium / Mini **2x faster**! See our [Phi-3 Medium notebook](https://colab.research.google.com/drive/1hhdhBa1j_hsymiW9m-WzxQtgqTH_NHqi?usp=sharing)
# 10. [**NEW**] We make Gemma-2 9b / 27b **2x faster**! See our [Gemma-2 9b notebook](https://colab.research.google.com/drive/1vIrqH5uYDQwsJ4-OO3DErvuv4pBgVwk4?usp=sharing)
# 11. [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)
# 12. [**NEW**] We make Mistral NeMo 12B 2x faster and fit in under 12GB of VRAM! [Mistral NeMo notebook](https://colab.research.google.com/drive/17d3U-CAIwzmbDRqbZ9NnpHxCkmXB6LZ0?usp=sharing)
#
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Support our work if you can! Thanks!
# </div>
